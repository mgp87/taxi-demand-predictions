# %%
from pathlib import Path
import requests

def download_file(year: int, month: int) -> Path:
    """"""
    URL = f'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{year}-{month:02d}.parquet'
    response = requests.get(URL)

    if response.status_code == 200:
        path = f'../data/raw/rides_{year}_{month:02d}.parquet'
        open(path, 'wb').write(response.content)
    else:
        raise Exception(f'Failed to download file from {URL} or it\'s not available')

# %%
download_file(2023, 1)

# %%
import pandas as pd
rides_df = pd.read_parquet('../data/raw/rides_2023_01.parquet')
rides_df.head(20)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1          2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2          2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3          1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4          2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# 5          2  2023-01-01 00:50:34   2023-01-01 01:02:52              1.0
# 6          2  2023-01-01 00:09:22   2023-01-01 00:19:49              1.0
# 7          2  2023-01-01 00:27:12   2023-01-01 00:49:56              1.0
# 8          2  2023-01-01 00:21:44   2023-01-01 00:36:40              1.0
# 9          2  2023-01-01 00:39:42   2023-01-01 00:50:36              1.0
# 10         2  2023-01-01 00:53:01   2023-01-01 01:01:45              1.0
# 11         1  2023-01-01 00:43:37   2023-01-01 01:17:18              4.0
# ...

# %%
rides_df = rides_df[["tpep_pickup_datetime", "PULocationID"]]

# %%
rides_df.rename(columns={"tpep_pickup_datetime": "pickup_datetime", "PULocationID": "pickup_location_id"}, inplace=True)
rides_df.head(20)
# Out:
#        pickup_datetime  pickup_location_id
# 0  2023-01-01 00:32:10                 161
# 1  2023-01-01 00:55:08                  43
# 2  2023-01-01 00:25:04                  48
# 3  2023-01-01 00:03:48                 138
# 4  2023-01-01 00:10:29                 107
# 5  2023-01-01 00:50:34                 161
# 6  2023-01-01 00:09:22                 239
# 7  2023-01-01 00:27:12                 142
# 8  2023-01-01 00:21:44                 164
# 9  2023-01-01 00:39:42                 141
# 10 2023-01-01 00:53:01                 234
# 11 2023-01-01 00:43:37                  79
# 12 2023-01-01 00:34:44                 164
# 13 2023-01-01 00:09:29                 138
# 14 2023-01-01 00:33:53                  33
# 15 2023-01-01 00:13:04                  79
# 16 2023-01-01 00:45:11                  90
# 17 2023-01-01 00:04:33                 113
# 18 2023-01-01 00:03:36                 237
# 19 2023-01-01 00:15:23                 143

# %%
rides_df['pickup_datetime'].describe()
# Out:
# count                       3066766
# mean     2023-01-17 00:22:26.288164
# min             2008-12-31 23:01:42
# 25%      2023-01-09 16:21:57.250000
# 50%      2023-01-17 08:42:29.500000
# 75%             2023-01-24 16:26:27
# max             2023-02-01 00:56:53
# Name: pickup_datetime, dtype: object

# %%
rides_df = rides_df[rides_df.pickup_datetime >= '2023-01-01']
rides_df = rides_df[rides_df.pickup_datetime < '2023-02-01']
rides_df.describe()
# Out:
#                   pickup_datetime  pickup_location_id
# count                     3066718        3.066718e+06
# mean   2023-01-17 00:27:48.391113        1.663983e+02
# min           2023-01-01 00:00:00        1.000000e+00
# 25%    2023-01-09 16:22:12.250000        1.320000e+02
# 50%    2023-01-17 08:42:40.500000        1.620000e+02
# 75%           2023-01-24 16:26:28        2.340000e+02
# max           2023-01-31 23:59:59        2.650000e+02
# std                           NaN        6.424394e+01

# %%
rides_df.to_parquet('../data/processed/rides_2023_01.parquet')
